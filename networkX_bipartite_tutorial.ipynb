# %%
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib as plt

# %%
B = nx.Graph()
B.add_nodes_from([1,2,3,4], bipartite=0)
B.add_nodes_from(['a','b','c'], bipartite=1)
B.add_edges_from([(1,'a'),(1,'b'),(2,'b'),(2,'c'),(3,'c'),(4,'a')])

# %%
nx.is_connected(B)
# Out:
# True

# %%
l, r = nx.bipartite.sets(B)
pos = {}

# %%
pos.update((node, (1, index)) for index, node in enumerate(l))
pos.update((node, (2, index)) for index, node in enumerate(r))

nx.draw(B,with_labels=True, pos=pos)
nx.draw(B, pos=pos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-0e2bc5a64a2a> in <module>()
#       4 nx.draw(B,with_labels=True, pos=pos)
#       5 nx.draw(B, pos=pos)
# ----> 6 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
projected = nx.projected_graph(B,['a','b','c'])
nx.draw(projected, with_labels=True, pos=pos)

# %%
projected = nx.projected_graph(B,[1,2,3,4])
nx.draw(projected, with_labels=True, pos=pos)

# %%
B = nx.Graph()
B.add_nodes_from([1,2,3,4], bipartite=0)
B.add_nodes_from(['a','b','c'], bipartite=1)
B.add_edges_from([(1,'a'),(1,'b'),(2,'b'),(2,'c'),(3,'c'),(4,'a')])

# %%
import pandas as pd
import networkx as nx
import mpld3

# %%
# Pandas의 DataFrame
df.sort('weight',ascending=False).head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-11dceb4a426f> in <module>()
#       1 # Pandas의 DataFrame
# ----> 2 df.sort('weight',ascending=False).head(3)
#
# NameError: name 'df' is not defined
